# %% [markdown]
# # Assignment 3: Exploring Tree-Based Regression Methods for 3D Sinusoidal Data
# ## DTSC 680: Applied Machine Learning
#
# ## Name:

# %% [markdown]
# ## Directions and Overview
#
# The main purpose of this assignment is for you to gain experience using tree-based methods to solve simple regression problems.  In this assignment, you will fit a `Gradient-Boosted Regression Tree`, a `Random Forest`, and a `Decision Tree` to a noisy 3D sinusoidal data set.  Since these models can be trained very quickly on the supplied data, I want you to first manually adjust hyperparameter values and observe their influence on the model's predictions.  That is, you should manually sweep the hyperparameter space and try to hone in on the optimal hyperparameter values, again, _manually_.  (Yep, that means guess-and-check: pick some values, train the model, observe the prediction curve, repeat.)
#
# But wait, there's more! Merely attempting to identify the optimal hyperparameter values is not enough.  Be sure to really get a visceral understanding of how altering a hyperparameter in turn alters the model predictions (i.e. the prediction curve).  This is how you will build your machine learning intuition!
#
# So, play around and build some models.  When you are done playing with hyperparameter values, you should try to set these values to the optimal values manually (you're likely going to be _way_ off).  Then, retrain the model.  Next in this assignment, we will perform several grid searches, so you'll be able to compare your "optimal" hyperparameter values with those computed from the grid search.
#
# We will visualize model predictions for the optimal `Gradient-Boosted Regression Tree`, a `Random Forest`, and `Decision Tree` models that were determined by the grid searches.  Next, you will compute the generalization error on the test set for the three models.

# %% [markdown]
# ## Preliminaries
#
# Let's import some common packages:

# %%
# Common imports
import matplotlib.pyplot as plt
import matplotlib as mpl
from mpl_toolkits import mplot3d
from matplotlib import cm
import numpy as np
import pandas as pd
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
import numpy as np
from sklearn.inspection import permutation_importance
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)
import os

# %%
##Setting
# Where to save the figures
PROJECT_ROOT_DIR = "."
FOLDER = "figures"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, FOLDER)

os.makedirs(IMAGES_PATH, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(IMAGES_PATH, fig_id + "." + fig_extension)
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)
    

def plot3Ddata(data_df):
    ### ENTER CODE HERE ###
    fig = plt.figure(figsize=(20, 10))
    x = data_df['x']
    y = data_df['y']
    z = data_df['z']
    #subplot 1 - top left
    ax = fig.add_subplot(2,2,1, projection='3d')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_zlabel('z')
    plt.xlim(0,14)
    plt.ylim(-6,6)
    ax.scatter3D(x, y, z, cmap='Blues')
    #line1
    ax.plot3D(x, y, z, 'black')
    ax.view_init(0,90)

    #subplot 2
    ax = fig.add_subplot(2,2,2, projection='3d')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_zlabel('z')
    plt.xlim(0,14)
    plt.ylim(-6,6)
    ax.scatter3D(x, y, z, cmap='Blues')
    
    #line 2
    ax.plot3D(x, y, z, 'black')
    ax.view_init(35,0)

    #subplot 3
    ax = fig.add_subplot(2,2,3, projection='3d')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_zlabel('z')
    plt.xlim(0,14)
    plt.ylim(-6,6)
    ax.scatter3D(x, y, z, cmap='Blues')

    #line 3
    ax.plot3D(x, y, z, 'black')
    ax.view_init(0,-90)

    #subplot 4
    ax = fig.add_subplot(2,2,4, projection='3d')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_zlabel('z')
    plt.xlim(0,14)
    plt.ylim(-6,6)
    ax.scatter3D(x, y, z, cmap='Blues')

    #line 4
    ax.plot3D(x, y, z, 'black')
    ax.view_init(30,30)
    
    
def plotscatter3Ddata(fit_x, fit_y, fit_z, scat_x, scat_y, scat_z):
    ### ENTER CODE HERE ###
    fig = plt.figure(figsize=(20, 10))
    x = fit_x
    y = fit_y
    z = fit_z
    
    #subplot 1 - top left
    ax = fig.add_subplot(2,2,1, projection='3d')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_zlabel('z')
    plt.xlim(0,14)
    plt.ylim(-6,6)
    ax.plot3D(x, y, z, 'gray')
    ax.scatter3D(scat_x, scat_y, scat_z, c=scat_z, cmap='Greens')
    
    #line1
    ax.plot3D(x, y, z, 'gray')
    ax.scatter3D(scat_x, scat_y, scat_z, c=scat_z, cmap='Greens')
    ax.view_init(0,90)
    
    #subplot 2
    ax = fig.add_subplot(2,2,2, projection='3d')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_zlabel('z')
    plt.xlim(0,14)
    plt.ylim(-6,6)
    ax.plot3D(x, y, z, 'gray')
    ax.scatter3D(scat_x, scat_y, scat_z, c=scat_z, cmap='Greens')
    
    #line 2
    ax.plot3D(x, y, z, 'gray')
    ax.scatter3D(scat_x, scat_y, scat_z, c=scat_z, cmap='Greens')
    ax.view_init(0,0)

    #subplot 3
    ax = fig.add_subplot(2,2,3, projection='3d')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_zlabel('z')
    plt.xlim(0,14)
    plt.ylim(-6,6)
    ax.plot3D(x, y, z, 'gray')
    ax.scatter3D(scat_x, scat_y, scat_z, c=scat_z, cmap='Greens')

    #line 3
    ax.plot3D(x, y, z, 'gray')
    ax.scatter3D(scat_x, scat_y, scat_z, c=scat_z, cmap='Greens')
    ax.view_init(0,-90)
    
    #subplot 4
    ax = fig.add_subplot(2,2,4, projection='3d')
    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_zlabel('z')
    plt.xlim(0,14)
    plt.ylim(-6,6)
    ax.plot3D(x, y, z, 'gray')
    ax.scatter3D(scat_x, scat_y, scat_z, c=scat_z, cmap='Greens')

    #line 4
    ax.plot3D(x, y, z, 'gray')
    ax.scatter3D(scat_x, scat_y, scat_z, c=scat_z, cmap='Greens')
    ax.view_init(45,30)

# %% [markdown]
# # Import and Split Data
#
# Complete the following:
#
#
#
# 1. Begin by importing the data from the file called `3DSinusoidal.csv`.  Name the returned DataFrame `data`.
#
# 2. Call [train_test_split()](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html) with a `test_size` of 20%.  `x` and `y` will be your feature data and `z` will be your response data. Save the output into `X_train`, `X_test`, `z_train`, and `z_test`, respectively.  Specify the `random_state` parameter to be `42` (do this throughout the entire note book).

# %%
### ENTER CODE HERE ###
data = pd.read_csv("3DSinusoidal.csv")
features = ['x','y']
X = data.loc[:, features]
z = data.loc[:, ['z']]
X_train, X_test, z_train, z_test = train_test_split(X, z, test_size=0.20, random_state=42, shuffle=True)

# %% [markdown]
# # Plot Data
#
# Simply plot your training data here, so that you know what you are working with.  You must define a function called `plot3Ddata`, which accepts a Pandas DataFrame (composed of 3 spatial coordinates) and uses `scatter3D()` to plot the data.  Use this function to plot only the training data (recall that you don't even want to look at the test set, until you are ready to calculate the generalization error).  You must place the definition of this function in the existing code cell of the above __Preliminaries__ section, and have nothing other than the function invocation in the below cell.
#
# You must emulate the graphs shown in the respective sections below. Each of the graphs will have four subplots. Note the various viewing angles that each subplot presents - you can achieve this with the view_init() method. Be sure to label your axes as shown.

# %%
train_df = pd.concat([X_train, z_train], axis=1).reindex(X_train.index)
plot3Ddata(train_df)

# %% [markdown]
# ## A Quick Note
#
# In the following sections you will be asked to plot the training data along with the model's predictions for that data superimposed on it.  You must write a function called `plotscatter3Ddata(fit_x, fit_y, fit_z, scat_x, scat_y, scat_z)` that will plot this figure.  The function accepts six parameters as input, shown in the function signature.  All six input parameters must be NumPy arrays. The Numpy arrays called fit_x and fit_y represent the x and y coordinates from the training data and fit_z represents the model predictions from those coordinates (i.e. the prediction curve). The three Numpy arrays called `scat_x, scat_y,` and  `scat_z` represent the x, y, and z coordinates of the training data.
#
# You must place the definition of the `plotscatter3Ddata(fit_x, fit_y, fit_z, scat_x, scat_y, scat_z)` function in the existing code cell of the above __Preliminaries__ section. (The function header is already there - you must complete the function definition.)
#
# You will use the `plotscatter3Ddata()` function in each of the below __Plot Model Predictions for Training Set__ portion of the three __Explore 3D Data__ sections, as well as the __Visualize Optimal Model Predictions__ section.
#
# ___Important: Below, you will be asked to plot the model's prediction curve along with the training data.  Even if you correctly train the model, you may find that your trendline is very ugly when you first plot it.  If this happens to you, try plotting the model's predictions using a scatter plot rather than a connected line plot.  You should be able to infer the problem and solution with the trendline from examining this new scatter plot of the model's predictions.___

# %% [markdown]
# # Explore 3D Data: GradientBoostingRegressor
#
# Fit a `GradientBoostingRegressor` model to this data.  You must manually assign values to the following hyperparameters.  You should "play around" by using different combinations of hyperparameter values to really get a feel for how they affect the model's predictions.  When you are done playing, set these to the best values you can for submission.  (It is totally fine if you don't elucidate the optimal values here; however, you will want to make sure your model is not excessively overfitting or underfitting the data.  Do this by examining the prediction curve generated by your model.  You will be graded, more exactly, on the values that you calculate later from performing several rounds of grid searches.)
#
#  - `learning_rate = <value>`
#  - `max_depth = <value>`
#  - `n_estimators = <value>`
#  - `random_state = 42`

# %%
from sklearn.ensemble import GradientBoostingRegressor
import matplotlib.pyplot as plt
import numpy as np
from sklearn.inspection import permutation_importance
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
params = {
    "n_estimators": 200,
    "max_depth": 3,
    "min_samples_split": 5,
    "learning_rate": 0.01
}

reg = GradientBoostingRegressor(**params)
reg.fit(X_train, z_train)
reg.score(X_train, z_train)
# Out:
# 0.8315028796884805

# %%
mse = mean_squared_error(z_test, reg.predict(X_test))
print("The mean squared error (MSE) on test set: {:.4f}".format(mse))
# Out:
# The mean squared error (MSE) on test set: 0.8563

# %%
z_pred = reg.predict(X_train)

# %% [markdown]
# ### Plot Model Predictions for Training Set
#
# Use the `plotscatter3Ddata(fit_x, fit_y, fit_z, scat_x, scat_y, scat_z)` function to plot the data and the prediction curve.

# %%
### ENTER CODE HERE ###
z_pred = reg.predict(X_train)
X_train_1 = X_train[:]

fit_x  = X_train['x']
fit_y = X_train['y']
fit_z = z_pred
scat_x  = X_train.loc[:, 'x'].to_numpy()
scat_y = X_train.loc[:, 'y'].to_numpy()
scat_z = z_train['z'].to_numpy()

plotscatter3Ddata(fit_x, fit_y, fit_z, scat_x, scat_y, scat_z)

# %% [markdown]
# # Explore 3D Data: RandomForestRegressor
#
# Fit a `RandomForestRegressor` model to this data.  You must manually assign values to the following hyperparameters.  You should "play around" by using different combinations of hyperparameter values to really get a feel for how they affect the model's predictions.  When you are done playing, set these to the best values you can for submission.  (It is totally fine if you don't elucidate the optimal values here; however, you will want to make sure your model is not excessively overfitting or underfitting the data.  Do this by examining the prediction curve generated by your model.  You will be graded, more exactly, on the values that you calculate later from performing several rounds of grid searches.)
#
#  - `min_samples_split = <value>`
#  - `max_depth = <value>`
#  - `n_estimators = <value>`
#  - `random_state = 42`

# %%
### ENTER CODE HERE ###
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
import numpy as np
from sklearn.inspection import permutation_importance
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
params = {
    "n_estimators": 200,
    "max_depth": 2,
    "min_samples_split": 5
}
X_train_1 = X_train[:]
z_train_1 = z_train[:]
X_train_1, z_train_1 = make_regression(n_features=2, n_informative=2, random_state=42, shuffle=True)
rf = RandomForestRegressor(**params)
rf.fit(X_train_1, z_train_1)
print(rf.score(X_train_1, z_train_1))
mse = mean_squared_error(z_test, rf.predict(X_test))
print("The mean squared error (MSE) on test set: {:.4f}".format(mse))
# Out:
# 0.8361550285353125
# The mean squared error (MSE) on test set: 3766.9930

# %% [markdown]
# ### Plot Model Predictions for Training Set
#
# Use the `plotscatter3Ddata(fit_x, fit_y, fit_z, scat_x, scat_y, scat_z)` function to plot the data and the prediction curve.

# %%
### ENTER CODE HERE ###
z_pred = rf.predict(X_train)
feature_x = ['x']
feature_y = ['y']

fit_x  = X_train['x']
fit_y = X_train['y']
fit_z = z_pred
scat_x  = X_train['x'].to_numpy()
scat_y = X_train['y'].to_numpy()
scat_z = z_train['z'].to_numpy()

plotscatter3Ddata(fit_x, fit_y, fit_z, scat_x, scat_y, scat_z)

# %% [markdown]
# # Explore 3D Data: DecisionTreeRegressor
#
# Fit a `DecisionTreeRegressor` model to this data.  You must manually assign values to the following hyperparameters.  You should "play around" by using different combinations of hyperparameter values to really get a feel for how they affect the model's predictions.  When you are done playing, set these to the best values you can for submission.  (It is totally fine if you don't elucidate the optimal values here; however, you will want to make sure your model is not excessively overfitting or underfitting the data.  Do this by examining the prediction curve generated by your model.  You will be graded, more exactly, on the values that you calculate later from performing several rounds of grid searches.)
#  - `splitter = <value>`
#  - `max_depth = <value>`
#  - `min_samples_split = <value>`
#  - `random_state = 42`

# %%
### ENTER CODE HERE ###
from sklearn.tree import DecisionTreeRegressor

params = {
    "splitter":'best',
    "max_depth": 9,
    "min_samples_split": 5,
    "random_state": 42
}

dt = DecisionTreeRegressor(**params)
dt.fit(X_train, z_train)
dt.score(X_train, z_train)
# Out:
# 0.9718391139811418

# %% [markdown]
# ### Plot Model Predictions for Training Set
#
# Use the `plotscatter3Ddata(fit_x, fit_y, fit_z, scat_x, scat_y, scat_z)` function to plot the data and the prediction curve.

# %%
### ENTER CODE HERE ###
z_pred = dt.predict(X_train)

fit_x  = X_train['x']
fit_y = X_train['y']
fit_z = z_pred
scat_x  = X_train['x'].to_numpy()
scat_  = X_train['y'].to_numpy()
scat_z = z_train['z'].to_numpy()

plotscatter3Ddata(fit_x, fit_y, fit_z, scat_x, scat_y, scat_z)

# %% [markdown]
# # Perform Grid Searches
#
# You will perform a series of grid searches, which will yield the optimal hyperparamter values for each of the three model types.  You can compare the values computed by the grid search with the values you manually found earlier.  How do these compare?
#
# You must perform a course-grained grid search, with a very broad range of values first.  Then, you perform a second grid search using a tighter range of values centered on those identified in the first grid search.  You may have to use another round of grid searching too (it took me at least three rounds of grid searches per model to ascertain the optimal hyperparameter values below).
#
# Note the following:
#
# 1. Be sure to clearly report the optimal hyperparameters in the designated location after you calculate them!
#
# 2. You must use `random_state=42` everywhere that it is needed in this notebook.
#
# 3. You must use grid search to compute the following hyperparameters:
#
#    GradientBoostingRegressor:
#
#      - `max_depth = <value>`
#      - `n_estimators = <value>`
#      - `learning_rate = <value>`
#
#    RandomForestRegressor:
#
#      - `max_depth = <value>`
#      - `n_estimators = <value>`
#      - `min_samples_split = <value>`
#
#    DecisionTreeRegressor:
#
#      - `splitter = <value>`
#      - `max_depth = <value>`
#      - `min_samples_split = <value>`
#
#
# 4. `learning rate` should be rounded to two decimals.
# 5. The number of cross-folds. Specify `cv=3`

# %% [markdown]
# ## Perform Individual Model Grid Searches
#
# In this section you will perform a series of grid searches to compute the optimal hyperparameter values for each of the three model types.

# %%
### ENTER CODE HERE ###

# -----
# Coarse-Grained GradientBoostingRegressor GridSearch
# -----

### ENTER CODE HERE ###
import pandas as pd
import xgboost as xgb
from sklearn.model_selection import GridSearchCV


params = { 'max_depth': [3,6,10],
           'learning_rate': [0.01, 0.05, 0.1],
           'n_estimators': [100, 500, 1000]}
xgbr = xgb.XGBRegressor(seed = 42)
clf = GridSearchCV(estimator=xgbr, 
                   param_grid=params,
                   scoring='neg_mean_squared_error', 
                   verbose=1)
grid_result = clf.fit(X_train, z_train)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
	print("%f (%f) with: %r" % (mean, stdev, param))

print("Best parameters:", grid_result.best_params_)
print("Lowest RMSE: ", (-grid_result.best_score_)**(1/2.0))
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Best: -0.875338 using {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 1000}
# -5.040969 (1.363901) with: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 100}
# -0.918094 (0.276866) with: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 500}
# -0.875338 (0.210952) with: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 1000}
# -4.302160 (1.284028) with: {'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 100}
# -0.913031 (0.284144) with: {'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 500}
# -0.925231 (0.251467) with: {'learning_rate': 0.01, 'max_depth': 6, 'n_estimators': 1000}
# -4.364290 (1.284302) with: {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 100}
# -0.972132 (0.232551) with: {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 500}
# -0.969903 (0.250429) with: {'learning_rate': 0.01, 'max_depth': 10, 'n_estimators': 1000}
# -0.917140 (0.285162) with: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
# -0.968235 (0.169660) with: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 500}
# -1.013863 (0.153227) with: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 1000}
# -0.927595 (0.289339) with: {'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 100}
# -0.968177 (0.268326) with: {'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 500}
# -0.968481 (0.268539) with: {'learning_rate': 0.05, 'max_depth': 6, 'n_estimators': 1000}
# -0.969393 (0.247786) with: {'learning_rate': 0.05, 'max_depth': 10, 'n_estimators': 100}
# -0.959022 (0.267603) with: {'learning_rate': 0.05, 'max_depth': 10, 'n_estimators': 500}
# -0.959022 (0.267603) with: {'learning_rate': 0.05, 'max_depth': 10, 'n_estimators': 1000}
# -0.882021 (0.219258) with: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
# -1.012645 (0.166501) with: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 500}
# -1.025242 (0.165557) with: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 1000}
# -0.924715 (0.262201) with: {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 100}
# -0.943765 (0.264401) with: {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 500}
# -0.943765 (0.264401) with: {'learning_rate': 0.1, 'max_depth': 6, 'n_estimators': 1000}
# -1.022360 (0.293116) with: {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 100}
# -1.022946 (0.294162) with: {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 500}
# -1.022946 (0.294162) with: {'learning_rate': 0.1, 'max_depth': 10, 'n_estimators': 1000}
# Best parameters: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 1000}
# Lowest RMSE:  0.9355950506993178

# %%
# -----
# Refined GradientBoostingRegressor GridSearch
# -----

### ENTER CODE HERE ###

params = { 'max_depth': [1,2,3],
           'learning_rate': [0.001, 0.005, 0.01],
           'n_estimators': [1000, 1500, 2000]}
xgbr = xgb.XGBRegressor(seed = 42)
clf = GridSearchCV(estimator=xgbr, 
                   param_grid=params,
                   scoring='neg_mean_squared_error', 
                   verbose=1)
grid_result = clf.fit(X_train, z_train)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
	print("%f (%f) with: %r" % (mean, stdev, param))

print("Best parameters:", grid_result.best_params_)
print("Lowest RMSE: ", (-grid_result.best_score_)**(1/2.0))
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Best: -0.849060 using {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 1500}
# -6.578775 (1.360538) with: {'learning_rate': 0.001, 'max_depth': 1, 'n_estimators': 1000}
# -4.796087 (1.027495) with: {'learning_rate': 0.001, 'max_depth': 1, 'n_estimators': 1500}
# -4.004492 (0.855990) with: {'learning_rate': 0.001, 'max_depth': 1, 'n_estimators': 2000}
# -5.492038 (1.440554) with: {'learning_rate': 0.001, 'max_depth': 2, 'n_estimators': 1000}
# -3.497575 (0.992744) with: {'learning_rate': 0.001, 'max_depth': 2, 'n_estimators': 1500}
# -2.513432 (0.727311) with: {'learning_rate': 0.001, 'max_depth': 2, 'n_estimators': 2000}
# -5.052630 (1.366141) with: {'learning_rate': 0.001, 'max_depth': 3, 'n_estimators': 1000}
# -3.018992 (0.980663) with: {'learning_rate': 0.001, 'max_depth': 3, 'n_estimators': 1500}
# -2.062635 (0.712293) with: {'learning_rate': 0.001, 'max_depth': 3, 'n_estimators': 2000}
# -2.844194 (0.781868) with: {'learning_rate': 0.005, 'max_depth': 1, 'n_estimators': 1000}
# -2.565451 (0.813650) with: {'learning_rate': 0.005, 'max_depth': 1, 'n_estimators': 1500}
# -2.315031 (0.772446) with: {'learning_rate': 0.005, 'max_depth': 1, 'n_estimators': 2000}
# -1.166039 (0.333133) with: {'learning_rate': 0.005, 'max_depth': 2, 'n_estimators': 1000}
# -0.922538 (0.248067) with: {'learning_rate': 0.005, 'max_depth': 2, 'n_estimators': 1500}
# -0.857761 (0.227977) with: {'learning_rate': 0.005, 'max_depth': 2, 'n_estimators': 2000}
# -0.920374 (0.275181) with: {'learning_rate': 0.005, 'max_depth': 3, 'n_estimators': 1000}
# -0.857454 (0.225519) with: {'learning_rate': 0.005, 'max_depth': 3, 'n_estimators': 1500}
# -0.871560 (0.199822) with: {'learning_rate': 0.005, 'max_depth': 3, 'n_estimators': 2000}
# -2.313190 (0.771486) with: {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 1000}
# -1.921413 (0.674679) with: {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 1500}
# -1.644568 (0.593841) with: {'learning_rate': 0.01, 'max_depth': 1, 'n_estimators': 2000}
# -0.856878 (0.228232) with: {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 1000}
# -0.849060 (0.222276) with: {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 1500}
# -0.851119 (0.207359) with: {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 2000}
# -0.875338 (0.210952) with: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 1000}
# -0.918612 (0.195024) with: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 1500}
# -0.949683 (0.172604) with: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 2000}
# Best parameters: {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 1500}
# Lowest RMSE:  0.9214446967636423

# %%
# -----
# Final GradientBoostingRegressor GridSearch
# -----

### ENTER CODE HERE ###
params = { 'max_depth': [2,3,4],
           'learning_rate': [0.01, 0.05, 0.1],
           'n_estimators': [1500, 1800, 2000]}
xgbr = xgb.XGBRegressor(seed = 42)
clf = GridSearchCV(estimator=xgbr, 
                   param_grid=params,
                   scoring='neg_mean_squared_error', 
                   verbose=1)
grid_result = clf.fit(X_train, z_train)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
	print("%f (%f) with: %r" % (mean, stdev, param))

print("Best parameters:", grid_result.best_params_)
print("Lowest RMSE: ", (-grid_result.best_score_)**(1/2.0))
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# Best: -0.845785 using {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 1800}
# -0.849060 (0.222276) with: {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 1500}
# -0.845785 (0.217391) with: {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 1800}
# -0.851119 (0.207359) with: {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 2000}
# -0.918612 (0.195024) with: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 1500}
# -0.936975 (0.182796) with: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 1800}
# -0.949683 (0.172604) with: {'learning_rate': 0.01, 'max_depth': 3, 'n_estimators': 2000}
# -0.915848 (0.198539) with: {'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 1500}
# -0.922160 (0.189279) with: {'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 1800}
# -0.926373 (0.185661) with: {'learning_rate': 0.01, 'max_depth': 4, 'n_estimators': 2000}
# -0.972085 (0.137237) with: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 1500}
# -0.986496 (0.132476) with: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 1800}
# -0.992540 (0.130305) with: {'learning_rate': 0.05, 'max_depth': 2, 'n_estimators': 2000}
# -1.025158 (0.150273) with: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 1500}
# -1.027680 (0.149811) with: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 1800}
# -1.028304 (0.150025) with: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 2000}
# -0.961761 (0.194526) with: {'learning_rate': 0.05, 'max_depth': 4, 'n_estimators': 1500}
# -0.961762 (0.194528) with: {'learning_rate': 0.05, 'max_depth': 4, 'n_estimators': 1800}
# -0.961762 (0.194528) with: {'learning_rate': 0.05, 'max_depth': 4, 'n_estimators': 2000}
# -1.011367 (0.121086) with: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 1500}
# -1.014912 (0.119826) with: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 1800}
# -1.016187 (0.119254) with: {'learning_rate': 0.1, 'max_depth': 2, 'n_estimators': 2000}
# -1.025243 (0.165557) with: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 1500}
# -1.025243 (0.165557) with: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 1800}
# -1.025243 (0.165557) with: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 2000}
# -0.919939 (0.173151) with: {'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 1500}
# -0.919939 (0.173151) with: {'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 1800}
# -0.919939 (0.173151) with: {'learning_rate': 0.1, 'max_depth': 4, 'n_estimators': 2000}
# Best parameters: {'learning_rate': 0.01, 'max_depth': 2, 'n_estimators': 1800}
# Lowest RMSE:  0.9196657252606115

# %% [markdown]
# On this dataset, the optimal model parameters for the `RandomForestRegressor` class are:
#
# - `max_depth = <value>`
# - `n_estimators = <value>`
# - `min_samples_split = <value>`

# %%
# -----
# Coarse-Grained RandomForestRegressor GridSearch
# -----

### ENTER CODE HERE ###
from sklearn.model_selection import GridSearchCV
params = { 'max_depth': [2,3,4, 10, 20, None],
           'min_samples_split': [2, 5, 6, 7, 8, 9, 10],
           'n_estimators': [200, 400, 600, 800, 1000]}
clf = GridSearchCV(estimator=RandomForestRegressor(), 
                   param_grid=params,
                   scoring='neg_mean_squared_error', 
                   verbose=1)
grid_result = clf.fit(X_train, z_train)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
	print("%f (%f) with: %r" % (mean, stdev, param))

print("Best parameters:", grid_result.best_params_)
print("Lowest RMSE: ", (-grid_result.best_score_)**(1/2.0))
# Out:
# Fitting 5 folds for each of 210 candidates, totalling 1050 fits
# Best: -0.846671 using {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 400}
# -2.564019 (0.705232) with: {'max_depth': 2, 'min_samples_split': 2, 'n_estimators': 200}
# -2.533754 (0.699285) with: {'max_depth': 2, 'min_samples_split': 2, 'n_estimators': 400}
# -2.545889 (0.698266) with: {'max_depth': 2, 'min_samples_split': 2, 'n_estimators': 600}
# -2.563027 (0.718092) with: {'max_depth': 2, 'min_samples_split': 2, 'n_estimators': 800}
# -2.552101 (0.707513) with: {'max_depth': 2, 'min_samples_split': 2, 'n_estimators': 1000}
# -2.545170 (0.692952) with: {'max_depth': 2, 'min_samples_split': 5, 'n_estimators': 200}
# -2.509183 (0.715474) with: {'max_depth': 2, 'min_samples_split': 5, 'n_estimators': 400}
# -2.538382 (0.693561) with: {'max_depth': 2, 'min_samples_split': 5, 'n_estimators': 600}
# -2.549734 (0.709076) with: {'max_depth': 2, 'min_samples_split': 5, 'n_estimators': 800}
# -2.535530 (0.714789) with: {'max_depth': 2, 'min_samples_split': 5, 'n_estimators': 1000}
# -2.560156 (0.699644) with: {'max_depth': 2, 'min_samples_split': 6, 'n_estimators': 200}
# -2.542037 (0.690104) with: {'max_depth': 2, 'min_samples_split': 6, 'n_estimators': 400}
# -2.531669 (0.703507) with: {'max_depth': 2, 'min_samples_split': 6, 'n_estimators': 600}
# -2.571131 (0.733397) with: {'max_depth': 2, 'min_samples_split': 6, 'n_estimators': 800}
# -2.558001 (0.711080) with: {'max_depth': 2, 'min_samples_split': 6, 'n_estimators': 1000}
# -2.567027 (0.732915) with: {'max_depth': 2, 'min_samples_split': 7, 'n_estimators': 200}
# -2.525639 (0.713025) with: {'max_depth': 2, 'min_samples_split': 7, 'n_estimators': 400}
# -2.538552 (0.705241) with: {'max_depth': 2, 'min_samples_split': 7, 'n_estimators': 600}
# -2.547977 (0.722945) with: {'max_depth': 2, 'min_samples_split': 7, 'n_estimators': 800}
# -2.551749 (0.707139) with: {'max_depth': 2, 'min_samples_split': 7, 'n_estimators': 1000}
# -2.550699 (0.704513) with: {'max_depth': 2, 'min_samples_split': 8, 'n_estimators': 200}
# -2.541131 (0.730618) with: {'max_depth': 2, 'min_samples_split': 8, 'n_estimators': 400}
# -2.572907 (0.727357) with: {'max_depth': 2, 'min_samples_split': 8, 'n_estimators': 600}
# -2.536564 (0.690652) with: {'max_depth': 2, 'min_samples_split': 8, 'n_estimators': 800}
# -2.528077 (0.683901) with: {'max_depth': 2, 'min_samples_split': 8, 'n_estimators': 1000}
# -2.591382 (0.752209) with: {'max_depth': 2, 'min_samples_split': 9, 'n_estimators': 200}
# -2.538811 (0.691629) with: {'max_depth': 2, 'min_samples_split': 9, 'n_estimators': 400}
# -2.534089 (0.719994) with: {'max_depth': 2, 'min_samples_split': 9, 'n_estimators': 600}
# -2.550894 (0.714365) with: {'max_depth': 2, 'min_samples_split': 9, 'n_estimators': 800}
# -2.540143 (0.704492) with: {'max_depth': 2, 'min_samples_split': 9, 'n_estimators': 1000}
# -2.564730 (0.739858) with: {'max_depth': 2, 'min_samples_split': 10, 'n_estimators': 200}
# -2.525603 (0.698153) with: {'max_depth': 2, 'min_samples_split': 10, 'n_estimators': 400}
# -2.550851 (0.720898) with: {'max_depth': 2, 'min_samples_split': 10, 'n_estimators': 600}
# -2.549615 (0.693333) with: {'max_depth': 2, 'min_samples_split': 10, 'n_estimators': 800}
# -2.565009 (0.716498) with: {'max_depth': 2, 'min_samples_split': 10, 'n_estimators': 1000}
# -2.098106 (0.830713) with: {'max_depth': 3, 'min_samples_split': 2, 'n_estimators': 200}
# -2.081714 (0.832089) with: {'max_depth': 3, 'min_samples_split': 2, 'n_estimators': 400}
# -2.050496 (0.800228) with: {'max_depth': 3, 'min_samples_split': 2, 'n_estimators': 600}
# -2.069783 (0.821081) with: {'max_depth': 3, 'min_samples_split': 2, 'n_estimators': 800}
# -2.077524 (0.821675) with: {'max_depth': 3, 'min_samples_split': 2, 'n_estimators': 1000}
# -2.098186 (0.837853) with: {'max_depth': 3, 'min_samples_split': 5, 'n_estimators': 200}
# -2.054070 (0.787143) with: {'max_depth': 3, 'min_samples_split': 5, 'n_estimators': 400}
# -2.067710 (0.815317) with: {'max_depth': 3, 'min_samples_split': 5, 'n_estimators': 600}
# -2.092467 (0.810009) with: {'max_depth': 3, 'min_samples_split': 5, 'n_estimators': 800}
# -2.057442 (0.828950) with: {'max_depth': 3, 'min_samples_split': 5, 'n_estimators': 1000}
# -2.063235 (0.814491) with: {'max_depth': 3, 'min_samples_split': 6, 'n_estimators': 200}
# -2.067958 (0.811450) with: {'max_depth': 3, 'min_samples_split': 6, 'n_estimators': 400}
# -2.092586 (0.839389) with: {'max_depth': 3, 'min_samples_split': 6, 'n_estimators': 600}
# -2.071544 (0.813047) with: {'max_depth': 3, 'min_samples_split': 6, 'n_estimators': 800}
# -2.048086 (0.807466) with: {'max_depth': 3, 'min_samples_split': 6, 'n_estimators': 1000}
# -2.093625 (0.779102) with: {'max_depth': 3, 'min_samples_split': 7, 'n_estimators': 200}
# -2.068427 (0.828484) with: {'max_depth': 3, 'min_samples_split': 7, 'n_estimators': 400}
# -2.061182 (0.806070) with: {'max_depth': 3, 'min_samples_split': 7, 'n_estimators': 600}
# -2.062061 (0.807363) with: {'max_depth': 3, 'min_samples_split': 7, 'n_estimators': 800}
# -2.073928 (0.821022) with: {'max_depth': 3, 'min_samples_split': 7, 'n_estimators': 1000}
# -2.070174 (0.820340) with: {'max_depth': 3, 'min_samples_split': 8, 'n_estimators': 200}
# -2.081639 (0.818365) with: {'max_depth': 3, 'min_samples_split': 8, 'n_estimators': 400}
# -2.076227 (0.795594) with: {'max_depth': 3, 'min_samples_split': 8, 'n_estimators': 600}
# -2.082252 (0.791739) with: {'max_depth': 3, 'min_samples_split': 8, 'n_estimators': 800}
# -2.074297 (0.807677) with: {'max_depth': 3, 'min_samples_split': 8, 'n_estimators': 1000}
# -2.067540 (0.794745) with: {'max_depth': 3, 'min_samples_split': 9, 'n_estimators': 200}
# -2.072669 (0.807625) with: {'max_depth': 3, 'min_samples_split': 9, 'n_estimators': 400}
# -2.064566 (0.809089) with: {'max_depth': 3, 'min_samples_split': 9, 'n_estimators': 600}
# -2.072840 (0.802526) with: {'max_depth': 3, 'min_samples_split': 9, 'n_estimators': 800}
# -2.074526 (0.808597) with: {'max_depth': 3, 'min_samples_split': 9, 'n_estimators': 1000}
# -2.080386 (0.776030) with: {'max_depth': 3, 'min_samples_split': 10, 'n_estimators': 200}
# -2.087516 (0.793648) with: {'max_depth': 3, 'min_samples_split': 10, 'n_estimators': 400}
# -2.086074 (0.809085) with: {'max_depth': 3, 'min_samples_split': 10, 'n_estimators': 600}
# -2.062415 (0.788128) with: {'max_depth': 3, 'min_samples_split': 10, 'n_estimators': 800}
# -2.090648 (0.812659) with: {'max_depth': 3, 'min_samples_split': 10, 'n_estimators': 1000}
# -1.180515 (0.459679) with: {'max_depth': 4, 'min_samples_split': 2, 'n_estimators': 200}
# -1.185049 (0.429921) with: {'max_depth': 4, 'min_samples_split': 2, 'n_estimators': 400}
# -1.193860 (0.450112) with: {'max_depth': 4, 'min_samples_split': 2, 'n_estimators': 600}
# -1.161586 (0.441284) with: {'max_depth': 4, 'min_samples_split': 2, 'n_estimators': 800}
# -1.185528 (0.437506) with: {'max_depth': 4, 'min_samples_split': 2, 'n_estimators': 1000}
# -1.178237 (0.442312) with: {'max_depth': 4, 'min_samples_split': 5, 'n_estimators': 200}
# -1.177723 (0.430615) with: {'max_depth': 4, 'min_samples_split': 5, 'n_estimators': 400}
# -1.198630 (0.455489) with: {'max_depth': 4, 'min_samples_split': 5, 'n_estimators': 600}
# -1.194552 (0.436021) with: {'max_depth': 4, 'min_samples_split': 5, 'n_estimators': 800}
# -1.177883 (0.436328) with: {'max_depth': 4, 'min_samples_split': 5, 'n_estimators': 1000}
# -1.185052 (0.479088) with: {'max_depth': 4, 'min_samples_split': 6, 'n_estimators': 200}
# -1.208449 (0.441528) with: {'max_depth': 4, 'min_samples_split': 6, 'n_estimators': 400}
# -1.177001 (0.436667) with: {'max_depth': 4, 'min_samples_split': 6, 'n_estimators': 600}
# -1.209117 (0.451576) with: {'max_depth': 4, 'min_samples_split': 6, 'n_estimators': 800}
# -1.193962 (0.454304) with: {'max_depth': 4, 'min_samples_split': 6, 'n_estimators': 1000}
# -1.191105 (0.482589) with: {'max_depth': 4, 'min_samples_split': 7, 'n_estimators': 200}
# -1.216039 (0.464294) with: {'max_depth': 4, 'min_samples_split': 7, 'n_estimators': 400}
# -1.207745 (0.467111) with: {'max_depth': 4, 'min_samples_split': 7, 'n_estimators': 600}
# -1.209399 (0.447831) with: {'max_depth': 4, 'min_samples_split': 7, 'n_estimators': 800}
# -1.206796 (0.429744) with: {'max_depth': 4, 'min_samples_split': 7, 'n_estimators': 1000}
# -1.266420 (0.485651) with: {'max_depth': 4, 'min_samples_split': 8, 'n_estimators': 200}
# -1.213612 (0.471727) with: {'max_depth': 4, 'min_samples_split': 8, 'n_estimators': 400}
# -1.230300 (0.462558) with: {'max_depth': 4, 'min_samples_split': 8, 'n_estimators': 600}
# -1.212903 (0.439604) with: {'max_depth': 4, 'min_samples_split': 8, 'n_estimators': 800}
# -1.219177 (0.458081) with: {'max_depth': 4, 'min_samples_split': 8, 'n_estimators': 1000}
# -1.219721 (0.431981) with: {'max_depth': 4, 'min_samples_split': 9, 'n_estimators': 200}
# -1.234637 (0.450653) with: {'max_depth': 4, 'min_samples_split': 9, 'n_estimators': 400}
# -1.227398 (0.455648) with: {'max_depth': 4, 'min_samples_split': 9, 'n_estimators': 600}
# -1.224959 (0.435323) with: {'max_depth': 4, 'min_samples_split': 9, 'n_estimators': 800}
# -1.236446 (0.444498) with: {'max_depth': 4, 'min_samples_split': 9, 'n_estimators': 1000}
# -1.233771 (0.423250) with: {'max_depth': 4, 'min_samples_split': 10, 'n_estimators': 200}
# -1.247569 (0.447455) with: {'max_depth': 4, 'min_samples_split': 10, 'n_estimators': 400}
# -1.249533 (0.456023) with: {'max_depth': 4, 'min_samples_split': 10, 'n_estimators': 600}
# -1.236973 (0.452082) with: {'max_depth': 4, 'min_samples_split': 10, 'n_estimators': 800}
# -1.251311 (0.465362) with: {'max_depth': 4, 'min_samples_split': 10, 'n_estimators': 1000}
# -0.872454 (0.304773) with: {'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 200}
# -0.863469 (0.305415) with: {'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 400}
# -0.873732 (0.303387) with: {'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 600}
# -0.866529 (0.290391) with: {'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 800}
# -0.851009 (0.274018) with: {'max_depth': 10, 'min_samples_split': 2, 'n_estimators': 1000}
# -0.910605 (0.301886) with: {'max_depth': 10, 'min_samples_split': 5, 'n_estimators': 200}
# -0.917416 (0.301785) with: {'max_depth': 10, 'min_samples_split': 5, 'n_estimators': 400}
# -0.909052 (0.288840) with: {'max_depth': 10, 'min_samples_split': 5, 'n_estimators': 600}
# -0.897425 (0.297873) with: {'max_depth': 10, 'min_samples_split': 5, 'n_estimators': 800}
# -0.890202 (0.281223) with: {'max_depth': 10, 'min_samples_split': 5, 'n_estimators': 1000}
# -0.934357 (0.303278) with: {'max_depth': 10, 'min_samples_split': 6, 'n_estimators': 200}
# -0.954111 (0.329937) with: {'max_depth': 10, 'min_samples_split': 6, 'n_estimators': 400}
# -0.921930 (0.310773) with: {'max_depth': 10, 'min_samples_split': 6, 'n_estimators': 600}
# -0.939821 (0.317133) with: {'max_depth': 10, 'min_samples_split': 6, 'n_estimators': 800}
# -0.929396 (0.320106) with: {'max_depth': 10, 'min_samples_split': 6, 'n_estimators': 1000}
# -0.989094 (0.336643) with: {'max_depth': 10, 'min_samples_split': 7, 'n_estimators': 200}
# -0.976519 (0.359993) with: {'max_depth': 10, 'min_samples_split': 7, 'n_estimators': 400}
# -0.975676 (0.370508) with: {'max_depth': 10, 'min_samples_split': 7, 'n_estimators': 600}
# -0.979967 (0.357971) with: {'max_depth': 10, 'min_samples_split': 7, 'n_estimators': 800}
# -0.987521 (0.361807) with: {'max_depth': 10, 'min_samples_split': 7, 'n_estimators': 1000}
# -1.027379 (0.416994) with: {'max_depth': 10, 'min_samples_split': 8, 'n_estimators': 200}
# -1.035865 (0.410524) with: {'max_depth': 10, 'min_samples_split': 8, 'n_estimators': 400}
# -1.037925 (0.403539) with: {'max_depth': 10, 'min_samples_split': 8, 'n_estimators': 600}
# -1.036692 (0.402593) with: {'max_depth': 10, 'min_samples_split': 8, 'n_estimators': 800}
# -1.029682 (0.393821) with: {'max_depth': 10, 'min_samples_split': 8, 'n_estimators': 1000}
# -1.086564 (0.427585) with: {'max_depth': 10, 'min_samples_split': 9, 'n_estimators': 200}
# -1.086465 (0.437943) with: {'max_depth': 10, 'min_samples_split': 9, 'n_estimators': 400}
# -1.085090 (0.445745) with: {'max_depth': 10, 'min_samples_split': 9, 'n_estimators': 600}
# -1.093718 (0.438896) with: {'max_depth': 10, 'min_samples_split': 9, 'n_estimators': 800}
# -1.092681 (0.431933) with: {'max_depth': 10, 'min_samples_split': 9, 'n_estimators': 1000}
# -1.127007 (0.450043) with: {'max_depth': 10, 'min_samples_split': 10, 'n_estimators': 200}
# -1.118076 (0.421951) with: {'max_depth': 10, 'min_samples_split': 10, 'n_estimators': 400}
# -1.153343 (0.458473) with: {'max_depth': 10, 'min_samples_split': 10, 'n_estimators': 600}
# -1.150377 (0.451471) with: {'max_depth': 10, 'min_samples_split': 10, 'n_estimators': 800}
# -1.135327 (0.449410) with: {'max_depth': 10, 'min_samples_split': 10, 'n_estimators': 1000}
# -0.862544 (0.297842) with: {'max_depth': 20, 'min_samples_split': 2, 'n_estimators': 200}
# -0.861528 (0.284414) with: {'max_depth': 20, 'min_samples_split': 2, 'n_estimators': 400}
# -0.882678 (0.304484) with: {'max_depth': 20, 'min_samples_split': 2, 'n_estimators': 600}
# -0.853814 (0.260562) with: {'max_depth': 20, 'min_samples_split': 2, 'n_estimators': 800}
# -0.866921 (0.287852) with: {'max_depth': 20, 'min_samples_split': 2, 'n_estimators': 1000}
# -0.889529 (0.271712) with: {'max_depth': 20, 'min_samples_split': 5, 'n_estimators': 200}
# -0.899128 (0.292320) with: {'max_depth': 20, 'min_samples_split': 5, 'n_estimators': 400}
# -0.897699 (0.300802) with: {'max_depth': 20, 'min_samples_split': 5, 'n_estimators': 600}
# -0.889151 (0.294076) with: {'max_depth': 20, 'min_samples_split': 5, 'n_estimators': 800}
# -0.909376 (0.306975) with: {'max_depth': 20, 'min_samples_split': 5, 'n_estimators': 1000}
# -0.908024 (0.290253) with: {'max_depth': 20, 'min_samples_split': 6, 'n_estimators': 200}
# -0.936153 (0.338183) with: {'max_depth': 20, 'min_samples_split': 6, 'n_estimators': 400}
# -0.928472 (0.326665) with: {'max_depth': 20, 'min_samples_split': 6, 'n_estimators': 600}
# -0.944428 (0.344532) with: {'max_depth': 20, 'min_samples_split': 6, 'n_estimators': 800}
# -0.938560 (0.327316) with: {'max_depth': 20, 'min_samples_split': 6, 'n_estimators': 1000}
# -0.961173 (0.363557) with: {'max_depth': 20, 'min_samples_split': 7, 'n_estimators': 200}
# -0.994081 (0.379790) with: {'max_depth': 20, 'min_samples_split': 7, 'n_estimators': 400}
# -0.988549 (0.377923) with: {'max_depth': 20, 'min_samples_split': 7, 'n_estimators': 600}
# -0.989640 (0.380648) with: {'max_depth': 20, 'min_samples_split': 7, 'n_estimators': 800}
# -0.989624 (0.359959) with: {'max_depth': 20, 'min_samples_split': 7, 'n_estimators': 1000}
# -1.019823 (0.414156) with: {'max_depth': 20, 'min_samples_split': 8, 'n_estimators': 200}
# -1.050339 (0.400644) with: {'max_depth': 20, 'min_samples_split': 8, 'n_estimators': 400}
# -1.038465 (0.416710) with: {'max_depth': 20, 'min_samples_split': 8, 'n_estimators': 600}
# -1.036719 (0.406821) with: {'max_depth': 20, 'min_samples_split': 8, 'n_estimators': 800}
# -1.021489 (0.393917) with: {'max_depth': 20, 'min_samples_split': 8, 'n_estimators': 1000}
# -1.081859 (0.434091) with: {'max_depth': 20, 'min_samples_split': 9, 'n_estimators': 200}
# -1.112507 (0.442241) with: {'max_depth': 20, 'min_samples_split': 9, 'n_estimators': 400}
# -1.087868 (0.424072) with: {'max_depth': 20, 'min_samples_split': 9, 'n_estimators': 600}
# -1.087684 (0.435060) with: {'max_depth': 20, 'min_samples_split': 9, 'n_estimators': 800}
# -1.100514 (0.425757) with: {'max_depth': 20, 'min_samples_split': 9, 'n_estimators': 1000}
# -1.135107 (0.416081) with: {'max_depth': 20, 'min_samples_split': 10, 'n_estimators': 200}
# -1.138916 (0.469445) with: {'max_depth': 20, 'min_samples_split': 10, 'n_estimators': 400}
# -1.152869 (0.457093) with: {'max_depth': 20, 'min_samples_split': 10, 'n_estimators': 600}
# -1.151428 (0.451073) with: {'max_depth': 20, 'min_samples_split': 10, 'n_estimators': 800}
# -1.144951 (0.444297) with: {'max_depth': 20, 'min_samples_split': 10, 'n_estimators': 1000}
# -0.868428 (0.276724) with: {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 200}
# -0.846671 (0.259763) with: {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 400}
# -0.856488 (0.273652) with: {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 600}
# -0.855582 (0.278634) with: {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 800}
# -0.867624 (0.272267) with: {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 1000}
# -0.901248 (0.292574) with: {'max_depth': None, 'min_samples_split': 5, 'n_estimators': 200}
# -0.910108 (0.291546) with: {'max_depth': None, 'min_samples_split': 5, 'n_estimators': 400}
# -0.901287 (0.290112) with: {'max_depth': None, 'min_samples_split': 5, 'n_estimators': 600}
# -0.896078 (0.282703) with: {'max_depth': None, 'min_samples_split': 5, 'n_estimators': 800}
# -0.897237 (0.281738) with: {'max_depth': None, 'min_samples_split': 5, 'n_estimators': 1000}
# -0.968688 (0.302776) with: {'max_depth': None, 'min_samples_split': 6, 'n_estimators': 200}
# -0.937090 (0.303510) with: {'max_depth': None, 'min_samples_split': 6, 'n_estimators': 400}
# -0.933014 (0.313595) with: {'max_depth': None, 'min_samples_split': 6, 'n_estimators': 600}
# -0.936190 (0.324385) with: {'max_depth': None, 'min_samples_split': 6, 'n_estimators': 800}
# -0.936904 (0.319984) with: {'max_depth': None, 'min_samples_split': 6, 'n_estimators': 1000}
# -0.980541 (0.382178) with: {'max_depth': None, 'min_samples_split': 7, 'n_estimators': 200}
# -0.983555 (0.352956) with: {'max_depth': None, 'min_samples_split': 7, 'n_estimators': 400}
# -0.991486 (0.345616) with: {'max_depth': None, 'min_samples_split': 7, 'n_estimators': 600}
# -0.975388 (0.371707) with: {'max_depth': None, 'min_samples_split': 7, 'n_estimators': 800}
# -0.993427 (0.375900) with: {'max_depth': None, 'min_samples_split': 7, 'n_estimators': 1000}
# -1.057992 (0.408970) with: {'max_depth': None, 'min_samples_split': 8, 'n_estimators': 200}
# -1.033010 (0.381361) with: {'max_depth': None, 'min_samples_split': 8, 'n_estimators': 400}
# -1.041253 (0.412205) with: {'max_depth': None, 'min_samples_split': 8, 'n_estimators': 600}
# -1.049313 (0.398308) with: {'max_depth': None, 'min_samples_split': 8, 'n_estimators': 800}
# -1.034917 (0.386830) with: {'max_depth': None, 'min_samples_split': 8, 'n_estimators': 1000}
# -1.100898 (0.448677) with: {'max_depth': None, 'min_samples_split': 9, 'n_estimators': 200}
# -1.072923 (0.450156) with: {'max_depth': None, 'min_samples_split': 9, 'n_estimators': 400}
# -1.086575 (0.430806) with: {'max_depth': None, 'min_samples_split': 9, 'n_estimators': 600}
# -1.078420 (0.431673) with: {'max_depth': None, 'min_samples_split': 9, 'n_estimators': 800}
# -1.094112 (0.445363) with: {'max_depth': None, 'min_samples_split': 9, 'n_estimators': 1000}
# -1.153970 (0.422288) with: {'max_depth': None, 'min_samples_split': 10, 'n_estimators': 200}
# -1.159964 (0.456098) with: {'max_depth': None, 'min_samples_split': 10, 'n_estimators': 400}
# -1.162783 (0.443561) with: {'max_depth': None, 'min_samples_split': 10, 'n_estimators': 600}
# -1.145698 (0.442943) with: {'max_depth': None, 'min_samples_split': 10, 'n_estimators': 800}
# -1.157187 (0.457873) with: {'max_depth': None, 'min_samples_split': 10, 'n_estimators': 1000}
# Best parameters: {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 400}
# Lowest RMSE:  0.9201471645430244

# %%
# -----
# Final-Grained DecisionTreeRegressor GridSearch
# -----

### ENTER CODE HERE ###
### ENTER CODE HERE ###
from sklearn.model_selection import GridSearchCV
params = { 'max_depth': [None, 2,3],
           'min_samples_split': [2,3,4,5],
           'n_estimators': [100, 200,300]}
clf = GridSearchCV(estimator=RandomForestRegressor(), 
                   param_grid=params,
                   scoring='neg_mean_squared_error', 
                   verbose=1)
grid_result = clf.fit(X_train, z_train)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
	print("%f (%f) with: %r" % (mean, stdev, param))

print("Best parameters:", grid_result.best_params_)
print("Lowest RMSE: ", (-grid_result.best_score_)**(1/2.0))
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# Best: -0.847999 using {'max_depth': None, 'min_samples_split': 3, 'n_estimators': 200}
# -0.848235 (0.243640) with: {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 100}
# -0.860838 (0.297731) with: {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 200}
# -0.874678 (0.302557) with: {'max_depth': None, 'min_samples_split': 2, 'n_estimators': 300}
# -0.878866 (0.277048) with: {'max_depth': None, 'min_samples_split': 3, 'n_estimators': 100}
# -0.847999 (0.280160) with: {'max_depth': None, 'min_samples_split': 3, 'n_estimators': 200}
# -0.856560 (0.274949) with: {'max_depth': None, 'min_samples_split': 3, 'n_estimators': 300}
# -0.872280 (0.283905) with: {'max_depth': None, 'min_samples_split': 4, 'n_estimators': 100}
# -0.868828 (0.255063) with: {'max_depth': None, 'min_samples_split': 4, 'n_estimators': 200}
# -0.876102 (0.277228) with: {'max_depth': None, 'min_samples_split': 4, 'n_estimators': 300}
# -0.883233 (0.302924) with: {'max_depth': None, 'min_samples_split': 5, 'n_estimators': 100}
# -0.913502 (0.274162) with: {'max_depth': None, 'min_samples_split': 5, 'n_estimators': 200}
# -0.911592 (0.309703) with: {'max_depth': None, 'min_samples_split': 5, 'n_estimators': 300}
# -2.499733 (0.695817) with: {'max_depth': 2, 'min_samples_split': 2, 'n_estimators': 100}
# -2.543480 (0.686562) with: {'max_depth': 2, 'min_samples_split': 2, 'n_estimators': 200}
# -2.540662 (0.711082) with: {'max_depth': 2, 'min_samples_split': 2, 'n_estimators': 300}
# -2.570940 (0.695594) with: {'max_depth': 2, 'min_samples_split': 3, 'n_estimators': 100}
# -2.543931 (0.707076) with: {'max_depth': 2, 'min_samples_split': 3, 'n_estimators': 200}
# -2.572660 (0.715242) with: {'max_depth': 2, 'min_samples_split': 3, 'n_estimators': 300}
# -2.576325 (0.703352) with: {'max_depth': 2, 'min_samples_split': 4, 'n_estimators': 100}
# -2.511277 (0.678932) with: {'max_depth': 2, 'min_samples_split': 4, 'n_estimators': 200}
# -2.543389 (0.724056) with: {'max_depth': 2, 'min_samples_split': 4, 'n_estimators': 300}
# -2.600234 (0.756429) with: {'max_depth': 2, 'min_samples_split': 5, 'n_estimators': 100}
# -2.508728 (0.667483) with: {'max_depth': 2, 'min_samples_split': 5, 'n_estimators': 200}
# -2.532865 (0.700406) with: {'max_depth': 2, 'min_samples_split': 5, 'n_estimators': 300}
# -2.086095 (0.838981) with: {'max_depth': 3, 'min_samples_split': 2, 'n_estimators': 100}
# -2.064665 (0.831553) with: {'max_depth': 3, 'min_samples_split': 2, 'n_estimators': 200}
# -2.088163 (0.844809) with: {'max_depth': 3, 'min_samples_split': 2, 'n_estimators': 300}
# -2.047966 (0.807451) with: {'max_depth': 3, 'min_samples_split': 3, 'n_estimators': 100}
# -2.083849 (0.817164) with: {'max_depth': 3, 'min_samples_split': 3, 'n_estimators': 200}
# -2.056653 (0.802706) with: {'max_depth': 3, 'min_samples_split': 3, 'n_estimators': 300}
# -2.074201 (0.808544) with: {'max_depth': 3, 'min_samples_split': 4, 'n_estimators': 100}
# -2.074104 (0.823798) with: {'max_depth': 3, 'min_samples_split': 4, 'n_estimators': 200}
# -2.076469 (0.798765) with: {'max_depth': 3, 'min_samples_split': 4, 'n_estimators': 300}
# -2.097950 (0.855979) with: {'max_depth': 3, 'min_samples_split': 5, 'n_estimators': 100}
# -2.034016 (0.776341) with: {'max_depth': 3, 'min_samples_split': 5, 'n_estimators': 200}
# -2.048642 (0.794872) with: {'max_depth': 3, 'min_samples_split': 5, 'n_estimators': 300}
# Best parameters: {'max_depth': None, 'min_samples_split': 3, 'n_estimators': 200}
# Lowest RMSE:  0.9208684131100928

# %% [markdown]
# On this dataset, the optimal model parameters for the `DecisionTreeRegressor` class are:
#
# - `splitter = <value>`
# - `max_depth = <value>`
# - `min_samples_split = <value>`

# %%
from sklearn.model_selection import GridSearchCV
params = { 'max_depth': [None,1, 2,3,4,5],
           'min_samples_split': [2,3,4,5],
           'splitter': ['random', 'best']}
clf = GridSearchCV(estimator=DecisionTreeRegressor(), 
                   param_grid=params,
                   scoring='neg_mean_squared_error', 
                   verbose=1)
grid_result = clf.fit(X_train, z_train)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
	print("%f (%f) with: %r" % (mean, stdev, param))

print("Best parameters:", grid_result.best_params_)
print("Lowest RMSE: ", (-grid_result.best_score_)**(1/2.0))
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# Best: -1.094323 using {'max_depth': None, 'min_samples_split': 5, 'splitter': 'best'}
# -2.255164 (0.537824) with: {'max_depth': None, 'min_samples_split': 2, 'splitter': 'random'}
# -1.142741 (0.296921) with: {'max_depth': None, 'min_samples_split': 2, 'splitter': 'best'}
# -1.680117 (0.926629) with: {'max_depth': None, 'min_samples_split': 3, 'splitter': 'random'}
# -1.209513 (0.301348) with: {'max_depth': None, 'min_samples_split': 3, 'splitter': 'best'}
# -1.577249 (0.680279) with: {'max_depth': None, 'min_samples_split': 4, 'splitter': 'random'}
# -1.124246 (0.362413) with: {'max_depth': None, 'min_samples_split': 4, 'splitter': 'best'}
# -2.369121 (1.045951) with: {'max_depth': None, 'min_samples_split': 5, 'splitter': 'random'}
# -1.094323 (0.365138) with: {'max_depth': None, 'min_samples_split': 5, 'splitter': 'best'}
# -5.137890 (0.593150) with: {'max_depth': 1, 'min_samples_split': 2, 'splitter': 'random'}
# -4.870078 (0.443401) with: {'max_depth': 1, 'min_samples_split': 2, 'splitter': 'best'}
# -4.705701 (0.442018) with: {'max_depth': 1, 'min_samples_split': 3, 'splitter': 'random'}
# -4.870078 (0.443401) with: {'max_depth': 1, 'min_samples_split': 3, 'splitter': 'best'}
# -5.533598 (0.790448) with: {'max_depth': 1, 'min_samples_split': 4, 'splitter': 'random'}
# -4.870078 (0.443401) with: {'max_depth': 1, 'min_samples_split': 4, 'splitter': 'best'}
# -5.789448 (1.346685) with: {'max_depth': 1, 'min_samples_split': 5, 'splitter': 'random'}
# -4.870078 (0.443401) with: {'max_depth': 1, 'min_samples_split': 5, 'splitter': 'best'}
# -5.064767 (1.115383) with: {'max_depth': 2, 'min_samples_split': 2, 'splitter': 'random'}
# -3.065366 (0.715555) with: {'max_depth': 2, 'min_samples_split': 2, 'splitter': 'best'}
# -4.658133 (1.070589) with: {'max_depth': 2, 'min_samples_split': 3, 'splitter': 'random'}
# -3.065366 (0.715555) with: {'max_depth': 2, 'min_samples_split': 3, 'splitter': 'best'}
# -4.391200 (0.999664) with: {'max_depth': 2, 'min_samples_split': 4, 'splitter': 'random'}
# -3.065366 (0.715555) with: {'max_depth': 2, 'min_samples_split': 4, 'splitter': 'best'}
# -5.299926 (0.989902) with: {'max_depth': 2, 'min_samples_split': 5, 'splitter': 'random'}
# -3.065366 (0.715555) with: {'max_depth': 2, 'min_samples_split': 5, 'splitter': 'best'}
# -3.131746 (0.622357) with: {'max_depth': 3, 'min_samples_split': 2, 'splitter': 'random'}
# -2.413492 (0.868369) with: {'max_depth': 3, 'min_samples_split': 2, 'splitter': 'best'}
# -3.785163 (1.000769) with: {'max_depth': 3, 'min_samples_split': 3, 'splitter': 'random'}
# -2.413492 (0.868369) with: {'max_depth': 3, 'min_samples_split': 3, 'splitter': 'best'}
# -3.870553 (0.885472) with: {'max_depth': 3, 'min_samples_split': 4, 'splitter': 'random'}
# -2.413492 (0.868369) with: {'max_depth': 3, 'min_samples_split': 4, 'splitter': 'best'}
# -3.883669 (1.021303) with: {'max_depth': 3, 'min_samples_split': 5, 'splitter': 'random'}
# -2.409417 (0.869771) with: {'max_depth': 3, 'min_samples_split': 5, 'splitter': 'best'}
# -3.838835 (0.919986) with: {'max_depth': 4, 'min_samples_split': 2, 'splitter': 'random'}
# -1.663286 (0.467596) with: {'max_depth': 4, 'min_samples_split': 2, 'splitter': 'best'}
# -3.245291 (1.358746) with: {'max_depth': 4, 'min_samples_split': 3, 'splitter': 'random'}
# -1.669115 (0.483338) with: {'max_depth': 4, 'min_samples_split': 3, 'splitter': 'best'}
# -3.507871 (1.664319) with: {'max_depth': 4, 'min_samples_split': 4, 'splitter': 'random'}
# -1.660997 (0.485435) with: {'max_depth': 4, 'min_samples_split': 4, 'splitter': 'best'}
# -2.519753 (0.852511) with: {'max_depth': 4, 'min_samples_split': 5, 'splitter': 'random'}
# -1.657192 (0.479368) with: {'max_depth': 4, 'min_samples_split': 5, 'splitter': 'best'}
# -2.454881 (0.836526) with: {'max_depth': 5, 'min_samples_split': 2, 'splitter': 'random'}
# -1.260795 (0.347055) with: {'max_depth': 5, 'min_samples_split': 2, 'splitter': 'best'}
# -2.930767 (1.435237) with: {'max_depth': 5, 'min_samples_split': 3, 'splitter': 'random'}
# -1.283855 (0.353680) with: {'max_depth': 5, 'min_samples_split': 3, 'splitter': 'best'}
# -3.685180 (1.366669) with: {'max_depth': 5, 'min_samples_split': 4, 'splitter': 'random'}
# -1.243075 (0.327219) with: {'max_depth': 5, 'min_samples_split': 4, 'splitter': 'best'}
# -2.676414 (1.080834) with: {'max_depth': 5, 'min_samples_split': 5, 'splitter': 'random'}
# -1.246681 (0.338235) with: {'max_depth': 5, 'min_samples_split': 5, 'splitter': 'best'}
# Best parameters: {'max_depth': None, 'min_samples_split': 5, 'splitter': 'best'}
# Lowest RMSE:  1.046098777973489

# %%
from sklearn.model_selection import GridSearchCV
params = { 'max_depth': [None,1, 2,3],
           'min_samples_split': [4,5,6],
           'splitter': ['random', 'best']}
clf = GridSearchCV(estimator=DecisionTreeRegressor(), 
                   param_grid=params,
                   scoring='neg_mean_squared_error', 
                   verbose=1)
grid_result = clf.fit(X_train, z_train)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
	print("%f (%f) with: %r" % (mean, stdev, param))

print("Best parameters:", grid_result.best_params_)
print("Lowest RMSE: ", (-grid_result.best_score_)**(1/2.0))
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# Best: -1.094323 using {'max_depth': None, 'min_samples_split': 5, 'splitter': 'best'}
# -2.171086 (1.099353) with: {'max_depth': None, 'min_samples_split': 4, 'splitter': 'random'}
# -1.124246 (0.362413) with: {'max_depth': None, 'min_samples_split': 4, 'splitter': 'best'}
# -2.312150 (1.209367) with: {'max_depth': None, 'min_samples_split': 5, 'splitter': 'random'}
# -1.094323 (0.365138) with: {'max_depth': None, 'min_samples_split': 5, 'splitter': 'best'}
# -1.631175 (0.560013) with: {'max_depth': None, 'min_samples_split': 6, 'splitter': 'random'}
# -1.119977 (0.301023) with: {'max_depth': None, 'min_samples_split': 6, 'splitter': 'best'}
# -5.206701 (1.268219) with: {'max_depth': 1, 'min_samples_split': 4, 'splitter': 'random'}
# -4.870078 (0.443401) with: {'max_depth': 1, 'min_samples_split': 4, 'splitter': 'best'}
# -4.866599 (0.294088) with: {'max_depth': 1, 'min_samples_split': 5, 'splitter': 'random'}
# -4.870078 (0.443401) with: {'max_depth': 1, 'min_samples_split': 5, 'splitter': 'best'}
# -5.126587 (0.751960) with: {'max_depth': 1, 'min_samples_split': 6, 'splitter': 'random'}
# -4.870078 (0.443401) with: {'max_depth': 1, 'min_samples_split': 6, 'splitter': 'best'}
# -5.139521 (0.947414) with: {'max_depth': 2, 'min_samples_split': 4, 'splitter': 'random'}
# -3.065366 (0.715555) with: {'max_depth': 2, 'min_samples_split': 4, 'splitter': 'best'}
# -3.888657 (1.425010) with: {'max_depth': 2, 'min_samples_split': 5, 'splitter': 'random'}
# -3.065366 (0.715555) with: {'max_depth': 2, 'min_samples_split': 5, 'splitter': 'best'}
# -5.026638 (0.968050) with: {'max_depth': 2, 'min_samples_split': 6, 'splitter': 'random'}
# -3.065366 (0.715555) with: {'max_depth': 2, 'min_samples_split': 6, 'splitter': 'best'}
# -3.567067 (1.046744) with: {'max_depth': 3, 'min_samples_split': 4, 'splitter': 'random'}
# -2.413492 (0.868369) with: {'max_depth': 3, 'min_samples_split': 4, 'splitter': 'best'}
# -4.633426 (0.666000) with: {'max_depth': 3, 'min_samples_split': 5, 'splitter': 'random'}
# -2.409417 (0.869771) with: {'max_depth': 3, 'min_samples_split': 5, 'splitter': 'best'}
# -5.128581 (0.736559) with: {'max_depth': 3, 'min_samples_split': 6, 'splitter': 'random'}
# -2.404387 (0.868560) with: {'max_depth': 3, 'min_samples_split': 6, 'splitter': 'best'}
# Best parameters: {'max_depth': None, 'min_samples_split': 5, 'splitter': 'best'}
# Lowest RMSE:  1.046098777973489

# %%
from sklearn.model_selection import GridSearchCV
params = { 'max_depth': [None,1, 2,3, 4,5],
           'min_samples_split': [4,5,6,7,8],
           'splitter': ['random', 'best']}
clf = GridSearchCV(estimator=DecisionTreeRegressor(), 
                   param_grid=params,
                   scoring='neg_mean_squared_error', 
                   verbose=1)
grid_result = clf.fit(X_train, z_train)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
means = grid_result.cv_results_['mean_test_score']
stds = grid_result.cv_results_['std_test_score']
params = grid_result.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
	print("%f (%f) with: %r" % (mean, stdev, param))

print("Best parameters:", grid_result.best_params_)
print("Lowest RMSE: ", (-grid_result.best_score_)**(1/2.0))
# Out:
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# Best: -1.094323 using {'max_depth': None, 'min_samples_split': 5, 'splitter': 'best'}
# -1.199568 (0.397398) with: {'max_depth': None, 'min_samples_split': 4, 'splitter': 'random'}
# -1.116597 (0.349211) with: {'max_depth': None, 'min_samples_split': 4, 'splitter': 'best'}
# -1.226427 (0.522505) with: {'max_depth': None, 'min_samples_split': 5, 'splitter': 'random'}
# -1.094323 (0.365138) with: {'max_depth': None, 'min_samples_split': 5, 'splitter': 'best'}
# -1.919498 (1.042245) with: {'max_depth': None, 'min_samples_split': 6, 'splitter': 'random'}
# -1.119977 (0.301023) with: {'max_depth': None, 'min_samples_split': 6, 'splitter': 'best'}
# -2.203373 (0.993641) with: {'max_depth': None, 'min_samples_split': 7, 'splitter': 'random'}
# -1.176323 (0.282698) with: {'max_depth': None, 'min_samples_split': 7, 'splitter': 'best'}
# -2.560535 (1.073874) with: {'max_depth': None, 'min_samples_split': 8, 'splitter': 'random'}
# -1.191527 (0.301602) with: {'max_depth': None, 'min_samples_split': 8, 'splitter': 'best'}
# -5.510719 (0.895929) with: {'max_depth': 1, 'min_samples_split': 4, 'splitter': 'random'}
# -4.870078 (0.443401) with: {'max_depth': 1, 'min_samples_split': 4, 'splitter': 'best'}
# -5.575230 (0.869270) with: {'max_depth': 1, 'min_samples_split': 5, 'splitter': 'random'}
# -4.870078 (0.443401) with: {'max_depth': 1, 'min_samples_split': 5, 'splitter': 'best'}
# -5.451674 (1.061996) with: {'max_depth': 1, 'min_samples_split': 6, 'splitter': 'random'}
# -4.870078 (0.443401) with: {'max_depth': 1, 'min_samples_split': 6, 'splitter': 'best'}
# -4.991571 (0.103619) with: {'max_depth': 1, 'min_samples_split': 7, 'splitter': 'random'}
# -4.870078 (0.443401) with: {'max_depth': 1, 'min_samples_split': 7, 'splitter': 'best'}
# -4.969923 (0.518756) with: {'max_depth': 1, 'min_samples_split': 8, 'splitter': 'random'}
# -4.870078 (0.443401) with: {'max_depth': 1, 'min_samples_split': 8, 'splitter': 'best'}
# -5.692282 (1.252470) with: {'max_depth': 2, 'min_samples_split': 4, 'splitter': 'random'}
# -3.065366 (0.715555) with: {'max_depth': 2, 'min_samples_split': 4, 'splitter': 'best'}
# -4.971061 (0.558067) with: {'max_depth': 2, 'min_samples_split': 5, 'splitter': 'random'}
# -3.065366 (0.715555) with: {'max_depth': 2, 'min_samples_split': 5, 'splitter': 'best'}
# -4.697112 (1.494948) with: {'max_depth': 2, 'min_samples_split': 6, 'splitter': 'random'}
# -3.065366 (0.715555) with: {'max_depth': 2, 'min_samples_split': 6, 'splitter': 'best'}
# -4.812629 (0.664593) with: {'max_depth': 2, 'min_samples_split': 7, 'splitter': 'random'}
# -3.065366 (0.715555) with: {'max_depth': 2, 'min_samples_split': 7, 'splitter': 'best'}
# -4.660391 (0.857615) with: {'max_depth': 2, 'min_samples_split': 8, 'splitter': 'random'}
# -3.065366 (0.715555) with: {'max_depth': 2, 'min_samples_split': 8, 'splitter': 'best'}
# -4.144416 (0.468165) with: {'max_depth': 3, 'min_samples_split': 4, 'splitter': 'random'}
# -2.413492 (0.868369) with: {'max_depth': 3, 'min_samples_split': 4, 'splitter': 'best'}
# -4.373547 (0.800308) with: {'max_depth': 3, 'min_samples_split': 5, 'splitter': 'random'}
# -2.409417 (0.869771) with: {'max_depth': 3, 'min_samples_split': 5, 'splitter': 'best'}
# -3.344992 (0.733218) with: {'max_depth': 3, 'min_samples_split': 6, 'splitter': 'random'}
# -2.404387 (0.868560) with: {'max_depth': 3, 'min_samples_split': 6, 'splitter': 'best'}
# -3.647589 (1.220094) with: {'max_depth': 3, 'min_samples_split': 7, 'splitter': 'random'}
# -2.404387 (0.868560) with: {'max_depth': 3, 'min_samples_split': 7, 'splitter': 'best'}
# -3.721395 (0.829704) with: {'max_depth': 3, 'min_samples_split': 8, 'splitter': 'random'}
# -2.404387 (0.868560) with: {'max_depth': 3, 'min_samples_split': 8, 'splitter': 'best'}
# -2.845497 (1.197592) with: {'max_depth': 4, 'min_samples_split': 4, 'splitter': 'random'}
# -1.660997 (0.485435) with: {'max_depth': 4, 'min_samples_split': 4, 'splitter': 'best'}
# -3.522704 (1.552756) with: {'max_depth': 4, 'min_samples_split': 5, 'splitter': 'random'}
# -1.657192 (0.479368) with: {'max_depth': 4, 'min_samples_split': 5, 'splitter': 'best'}
# -3.457911 (0.799962) with: {'max_depth': 4, 'min_samples_split': 6, 'splitter': 'random'}
# -1.653597 (0.474468) with: {'max_depth': 4, 'min_samples_split': 6, 'splitter': 'best'}
# -4.459504 (0.791875) with: {'max_depth': 4, 'min_samples_split': 7, 'splitter': 'random'}
# -1.649757 (0.467130) with: {'max_depth': 4, 'min_samples_split': 7, 'splitter': 'best'}
# -3.928830 (0.454976) with: {'max_depth': 4, 'min_samples_split': 8, 'splitter': 'random'}
# -1.663133 (0.464146) with: {'max_depth': 4, 'min_samples_split': 8, 'splitter': 'best'}
# -4.014032 (1.811868) with: {'max_depth': 5, 'min_samples_split': 4, 'splitter': 'random'}
# -1.243075 (0.327219) with: {'max_depth': 5, 'min_samples_split': 4, 'splitter': 'best'}
# -2.909995 (0.872115) with: {'max_depth': 5, 'min_samples_split': 5, 'splitter': 'random'}
# -1.246681 (0.338235) with: {'max_depth': 5, 'min_samples_split': 5, 'splitter': 'best'}
# -3.790636 (1.670553) with: {'max_depth': 5, 'min_samples_split': 6, 'splitter': 'random'}
# -1.244898 (0.334596) with: {'max_depth': 5, 'min_samples_split': 6, 'splitter': 'best'}
# -3.522247 (1.530629) with: {'max_depth': 5, 'min_samples_split': 7, 'splitter': 'random'}
# -1.266394 (0.328589) with: {'max_depth': 5, 'min_samples_split': 7, 'splitter': 'best'}
# -3.517689 (1.033314) with: {'max_depth': 5, 'min_samples_split': 8, 'splitter': 'random'}
# -1.293886 (0.331107) with: {'max_depth': 5, 'min_samples_split': 8, 'splitter': 'best'}
# Best parameters: {'max_depth': None, 'min_samples_split': 5, 'splitter': 'best'}
# Lowest RMSE:  1.046098777973489

# %% [markdown]
# # Visualize Optimal Model Predictions
#
# In the previous section you performed a series of grid searches designed to identify the optimal hyperparameter values for all three models.  Now, use the `best_params_` attribute of the grid search objects from above to create the three optimal models below.  For each model, visualize the models predictions on the training set - this is what we mean by the "prediction curve" of the model.
#
# ### Create Optimal GradientBoostingRegressor Model

# %%
### ENTER CODE HERE ###
params = {
    "n_estimators": 1800,
    "max_depth": 2,
    "min_samples_split": 5,
    "learning_rate": 0.01
}

reg = GradientBoostingRegressor(**params)
reg.fit(X_train, z_train)
reg.score(X_train, z_train)
# Out:
# 0.9795399474605078

# %% [markdown]
# ### Plot Model Predictions for Training Set
#
# Use the `plotscatter3Ddata(fit_x, fit_y, fit_z, scat_x, scat_y, scat_z)` function to plot the data and the prediction curve.

# %%
### ENTER CODE HERE ###
z_pred = reg.predict(X_train)
X_train_1 = X_train[:]

fit_x  = X_train['x']
fit_y = X_train['y']
fit_z = z_pred
scat_x  = X_train.loc[:, 'x'].to_numpy()
scat_y = X_train.loc[:, 'y'].to_numpy()
scat_z = z_train['z'].to_numpy()

plotscatter3Ddata(fit_x, fit_y, fit_z, scat_x, scat_y, scat_z)

# %% [markdown]
# ### Create Optimal RandomForestRegressor Model

# %%
### ENTER CODE HERE ###
params = {
    "n_estimators": 100,
    "max_depth": None,
    "min_samples_split": 4
}
X_train_1 = X_train[:]
z_train_1 = z_train[:]
X_train_1, z_train_1 = make_regression(n_features=2, n_informative=2, random_state=42, shuffle=True)
rf = RandomForestRegressor(**params)
rf.fit(X_train_1, z_train_1)
print(rf.score(X_train_1, z_train_1))
mse = mean_squared_error(z_test, rf.predict(X_test))
print("The mean squared error (MSE) on test set: {:.4f}".format(mse))
# Out:
# 0.98684156326513
# The mean squared error (MSE) on test set: 15524.4756

# %% [markdown]
# ### Plot Model Predictions for Training Set
#
# Use the `plotscatter3Ddata(fit_x, fit_y, fit_z, scat_x, scat_y, scat_z)` function to plot the data and the prediction curve.

# %%
### ENTER CODE HERE ###
z_pred = rf.predict(X_train_1)
feature_x = ['x']
feature_y = ['y']

fit_x  = X_train['x']
fit_y = X_train['y']
fit_z = z_pred
scat_x  = X_train['x'].to_numpy()
scat_y = X_train['y'].to_numpy()
scat_z = z_train['z'].to_numpy()

plotscatter3Ddata(fit_x, fit_y, fit_z, scat_x, scat_y, scat_z)

# %% [markdown]
# ### Create Optimal DecisionTreeRegressor Model

# %%
### ENTER CODE HERE ###
params = {
    "splitter":'best',
    "max_depth": None,
    "min_samples_split": 5,
    "random_state": 42
}

dt = DecisionTreeRegressor(**params)
dt.fit(X_train, z_train)
dt.score(X_train, z_train)
# Out:
# 0.9718391139811418

# %% [markdown]
# ### Plot Model Predictions for Training Set
#
# Use the `plotscatter3Ddata(fit_x, fit_y, fit_z, scat_x, scat_y, scat_z)` function to plot the data and the prediction curve.

# %%
### ENTER CODE HERE ###
z_pred = dt.predict(X_train)

fit_x  = X_train['x']
fit_y = X_train['y']
fit_z = z_pred
scat_x  = X_train['x'].to_numpy()
scat_  = X_train['y'].to_numpy()
scat_z = z_train['z'].to_numpy()

plotscatter3Ddata(fit_x, fit_y, fit_z, scat_x, scat_y, scat_z)

# %% [markdown]
# # Compute Generalization Error
#
# Compute the generalization error for each of the optimal models computed above.  Use MSE as the generalization error metric.  Round your answers to four significant digits.  Print the generalization error for all three models.

# %%
### ENTER CODE HERE ###
mse_xg = mean_squared_error(z_train, reg.predict(X_train))
print("The mean squared error (MSE) on XGBOOST: {:.4f}".format(mse_xg))
mse_rf = mean_squared_error(z_train_1, rf.predict(X_train_1))
print("The mean squared error (MSE) on Random Forest: {:.4f}".format(mse_rf))
mse_dt = mean_squared_error(z_train, dt.predict(X_train))
print("The mean squared error (MSE) on Decision Tree: {:.4f}".format(mse_dt))
# Out:
# The mean squared error (MSE) on XGBOOST: 0.1094
# The mean squared error (MSE) on Random Forest: 149.5331
# The mean squared error (MSE) on Decision Tree: 0.1506
